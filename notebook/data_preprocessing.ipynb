# %%
# Install pandas using conda (preferred for Anaconda environments)
# !conda install -y pandas

# Then import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# !conda install -y pandas matplotlib seaborn
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.5.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/raw/Battery_dataset.csv")
df.head()
# Out:
#    cycle       chI       chV        chT    disI   disV  disT       BCt  SOH  \
# 0      1 -0.004902  4.191492  24.330034 -0.0006  0.000    24  1.856487  1.0
# 1      1 -0.001478  4.190749  24.325993 -0.0006  4.206    24  1.856487  1.0
# 2      1 -2.012528  3.974871  24.389085 -1.9982  3.062    24  1.856487  1.0
# 3      1 -2.013979  3.951717  24.544752 -1.9982  3.030    24  1.856487  1.0
# 4      1 -2.011144  3.934352  24.731385 -1.9982  3.011    24  1.856487  1.0
#
#   battery_id  RUL
# 0         B5  167
# 1         B5  167
# 2         B5  167
# 3         B5  167
# 4         B5  167

# %%
df.tail()
# Out:
#         cycle       chI       chV        chT    disI  disV  disT       BCt  \
# 185716    132 -0.002426  3.443760  35.383979  0.0006   0.0    24  1.341051
# 185717    132 -0.000981  3.453271  35.179732  0.0006   0.0    24  1.341051
# 185718    132  0.000209  3.461963  34.977000  0.0006   0.0    24  1.341051
# 185719    132  0.001516  3.469907  34.785943  0.0006   0.0    24  1.341051
# 185720    132 -0.001940  3.477277  34.581660  0.0006   0.0    24  1.341051
#
#              SOH battery_id  RUL
# 185716  0.722937        B18    0
# 185717  0.722937        B18    0
# 185718  0.722937        B18    0
# 185719  0.722937        B18    0
# 185720  0.722937        B18    0

# %%
df.info
# Out:
# <bound method DataFrame.info of         cycle       chI       chV        chT    disI   disV  disT       BCt  \
# 0           1 -0.004902  4.191492  24.330034 -0.0006  0.000    24  1.856487
# 1           1 -0.001478  4.190749  24.325993 -0.0006  4.206    24  1.856487
# 2           1 -2.012528  3.974871  24.389085 -1.9982  3.062    24  1.856487
# 3           1 -2.013979  3.951717  24.544752 -1.9982  3.030    24  1.856487
# 4           1 -2.011144  3.934352  24.731385 -1.9982  3.011    24  1.856487
# ...       ...       ...       ...        ...     ...    ...   ...       ...
# 185716    132 -0.002426  3.443760  35.383979  0.0006  0.000    24  1.341051
# 185717    132 -0.000981  3.453271  35.179732  0.0006  0.000    24  1.341051
# 185718    132  0.000209  3.461963  34.977000  0.0006  0.000    24  1.341051
# 185719    132  0.001516  3.469907  34.785943  0.0006  0.000    24  1.341051
# 185720    132 -0.001940  3.477277  34.581660  0.0006  0.000    24  1.341051
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185721 entries, 0 to 185720
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   cycle       185721 non-null  int64
#  1   chI         185721 non-null  float64
#  2   chV         185721 non-null  float64
#  3   chT         185721 non-null  float64
#  4   disI        185721 non-null  float64
#  5   disV        185721 non-null  float64
#  6   disT        185721 non-null  int64
#  7   BCt         185721 non-null  float64
#  8   SOH         185721 non-null  float64
#  9   battery_id  185721 non-null  object
#  10  RUL         185721 non-null  int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 15.6+ MB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(df["cycle"], df["SOH"])
plt.xlabel("Cycle")
plt.ylabel("State of health")
plt.title("Battery Degradation Over Cycles")
plt.show()

# %%
import seaborn as sns
numeric_df = df.select_dtypes(include=['number']) # bcz non numeric values like batteryid cause prblm for corr function
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Missing values count:")
print(df.isna().sum())
print()

print("Missing values percentage:")
print((df.isna().mean() * 100).round(2))
# Out:
# Missing values count:
# cycle         0
# chI           0
# chV           0
# chT           0
# disI          0
# disV          0
# disT          0
# BCt           0
# SOH           0
# battery_id    0
# RUL           0
# dtype: int64
#
# Missing values percentage:
# cycle         0.0
# chI           0.0
# chV           0.0
# chT           0.0
# disI          0.0
# disV          0.0
# disT          0.0
# BCt           0.0
# SOH           0.0
# battery_id    0.0
# RUL           0.0
# dtype: float64

# %%
##descriptive statistics
df.describe
# Out:
# <bound method NDFrame.describe of         cycle       chI       chV        chT    disI   disV  disT       BCt  \
# 0           1 -0.004902  4.191492  24.330034 -0.0006  0.000    24  1.856487
# 1           1 -0.001478  4.190749  24.325993 -0.0006  4.206    24  1.856487
# 2           1 -2.012528  3.974871  24.389085 -1.9982  3.062    24  1.856487
# 3           1 -2.013979  3.951717  24.544752 -1.9982  3.030    24  1.856487
# 4           1 -2.011144  3.934352  24.731385 -1.9982  3.011    24  1.856487
# ...       ...       ...       ...        ...     ...    ...   ...       ...
# 185716    132 -0.002426  3.443760  35.383979  0.0006  0.000    24  1.341051
# 185717    132 -0.000981  3.453271  35.179732  0.0006  0.000    24  1.341051
# 185718    132  0.000209  3.461963  34.977000  0.0006  0.000    24  1.341051
# 185719    132  0.001516  3.469907  34.785943  0.0006  0.000    24  1.341051
# 185720    132 -0.001940  3.477277  34.581660  0.0006  0.000    24  1.341051
#
# ...

# %%
plt.figure(figsize=(10,5))
for battery in df["battery_id"].unique():
    subset=df[df["battery_id"]==battery]
    plt.plot(subset["cycle"],subset["RUL"],label=battery)



plt.title("cycle vs RUL")
plt.legend()
plt.show()

# %%
import seaborn as sns

numeric_cols = ['cycle', 'chI', 'chV', 'chT', 'disI', 'disV', 'disT', 'BCt', 'SOH', 'RUL']

plt.figure(figsize=(14,6))
sns.boxplot(data=df[numeric_cols])
plt.title("Boxplots of Numeric Features")
#plt.xticks(rotation=45)
plt.show()

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.99060022 0.98324172 ... 0.         0.79711144 1.        ]
#  [0.         0.99227565 0.98294418 ... 0.         0.79711144 1.        ]
#  [0.         0.0081091  0.89646477 ... 0.         0.79711144 1.        ]
#  ...
#  [0.78443114 0.99310118 0.69099701 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.9937408  0.69417958 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.99204953 0.69713172 ... 0.         0.21239821 0.36028999]]

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.99060022 0.98324172 ... 0.         0.79711144 1.        ]
#  [0.         0.99227565 0.98294418 ... 0.         0.79711144 1.        ]
#  [0.         0.0081091  0.89646477 ... 0.         0.79711144 1.        ]
#  ...
#  [0.78443114 0.99310118 0.69099701 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.9937408  0.69417958 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.99204953 0.69713172 ... 0.         0.21239821 0.36028999]]

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.99060022 0.98324172 ... 0.         0.79711144 1.        ]
#  [0.         0.99227565 0.98294418 ... 0.         0.79711144 1.        ]
#  [0.         0.0081091  0.89646477 ... 0.         0.79711144 1.        ]
#  ...
#  [0.78443114 0.99310118 0.69099701 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.9937408  0.69417958 ... 0.         0.21239821 0.36028999]
#  [0.78443114 0.99204953 0.69713172 ... 0.         0.21239821 0.36028999]]

# %%
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)# this just makes data readable for better debugging
print(x_scaled)
# Out:
#            cycle       chI       chV       chT     disI      disV  disT  \
# 0       0.000000  0.990600  0.983242  0.099077  0.49985  0.000000   0.0
# 1       0.000000  0.992276  0.982944  0.098875  0.49985  0.989880   0.0
# 2       0.000000  0.008109  0.896465  0.102032  0.00045  0.720640   0.0
# 3       0.000000  0.007399  0.887189  0.109822  0.00045  0.713109   0.0
# 4       0.000000  0.008787  0.880233  0.119162  0.00045  0.708637   0.0
# ...          ...       ...       ...       ...      ...       ...   ...
# 185716  0.784431  0.991812  0.683705  0.652264  0.50015  0.000000   0.0
# 185717  0.784431  0.992519  0.687515  0.642043  0.50015  0.000000   0.0
# 185718  0.784431  0.993101  0.690997  0.631897  0.50015  0.000000   0.0
# 185719  0.784431  0.993741  0.694180  0.622336  0.50015  0.000000   0.0
# 185720  0.784431  0.992050  0.697132  0.612113  0.50015  0.000000   0.0
#
#              BCt      SOH
# 0       0.797111  1.00000
# 1       0.797111  1.00000
# ...

# %%
x_scaled_df=x_scaled.copy()
x_scaled_df["battery_id"]=df["battery_id"].values
x_scaled_df["RUL"]=df["RUL"].values
print(x_scaled_df)
# Out:
#            cycle       chI       chV       chT     disI      disV  disT  \
# 0       0.000000  0.990600  0.983242  0.099077  0.49985  0.000000   0.0
# 1       0.000000  0.992276  0.982944  0.098875  0.49985  0.989880   0.0
# 2       0.000000  0.008109  0.896465  0.102032  0.00045  0.720640   0.0
# 3       0.000000  0.007399  0.887189  0.109822  0.00045  0.713109   0.0
# 4       0.000000  0.008787  0.880233  0.119162  0.00045  0.708637   0.0
# ...          ...       ...       ...       ...      ...       ...   ...
# 185716  0.784431  0.991812  0.683705  0.652264  0.50015  0.000000   0.0
# 185717  0.784431  0.992519  0.687515  0.642043  0.50015  0.000000   0.0
# 185718  0.784431  0.993101  0.690997  0.631897  0.50015  0.000000   0.0
# 185719  0.784431  0.993741  0.694180  0.622336  0.50015  0.000000   0.0
# 185720  0.784431  0.992050  0.697132  0.612113  0.50015  0.000000   0.0
#
#              BCt      SOH battery_id  RUL
# 0       0.797111  1.00000         B5  167
# ...

# %%
feature_col=[col for col in x_scaled_df.columns if col not in ["battery_id","RUL"]]
target_col='RUL'
print("feature column",feature_col)
print(" target column",target_col)
# Out:
# feature column ['cycle', 'chI', 'chV', 'chT', 'disI', 'disV', 'disT', 'BCt', 'SOH']
#  target column RUL

# %%
x_scaled_df.to_csv("processed_data.csv", index=False)

# %%
print(x_scaled_df["battery_id"].unique())
# Out:
# ['B5' 'B6' 'B7' 'B18']

# %%
train_batteries = ["B5","B6","B18"] 
test_batteries = ["B7"]
print(test_batteries)
#verify no overlap

# print(set(train_batteries)&set(test_batteries))
#intersection
# Out:
# ['B7']

# %%
train_dataset=x_scaled_df[x_scaled_df["battery_id"].isin(train_batteries)]
test_dataset=x_scaled_df[x_scaled_df["battery_id"].isin(test_batteries)]
print(train_dataset["battery_id"].unique())
print(test_dataset["battery_id"].unique())
train_dataset.to_csv("train_dataset.csv")
# Out:
# ['B5' 'B6' 'B18']
# ['B7']

# %%
import json
split_info={
    "train_batteries":["B5","B6","B18"],
    "test_batteries":["B7"]

}
with open("../data/processed/split.json","w") as f:
    json.dump(split_info,f,indent=4)

# %%
train_dataset.to_csv("../data/processed/train_dataset.csv",index=False)
test_dataset.to_csv("../data/processed/test_dataset.csv",index=False)
