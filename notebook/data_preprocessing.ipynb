# %%
# Install pandas using conda (preferred for Anaconda environments)
# !conda install -y pandas

# Then import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# !conda install -y pandas matplotlib seaborn
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/raw/Battery_dataset.csv")
df.head()
# Out:
#   battery_id  cycle       chI       chV        chT      disI      disV  \
# 0         B5      1  1.440147  4.254682  23.988733  1.894407  3.273523
# 1         B5      2  1.416595  4.159825  25.665347  1.829949  4.038741
# 2         B5      3  1.420272  4.276323  25.407910  1.942105  3.214433
# 3         B5      4  1.337680  4.236697  27.069757  2.073577  3.134529
# 4         B5      5  1.263946  4.142791  26.478353  2.049885  3.729341
#
#         disT       BCt        SOH  RUL
# 0  32.980834  1.986196  99.309790  219
# 1  32.257920  1.986240  99.311985  218
# 2  35.134801  1.984252  99.212608  217
# 3  32.082988  1.969236  98.461812  216
# 4  32.483154  1.974862  98.743106  215

# %%
df.info
# Out:
# <bound method DataFrame.info of     battery_id  cycle       chI       chV        chT      disI      disV  \
# 0           B5      1  1.440147  4.254682  23.988733  1.894407  3.273523
# 1           B5      2  1.416595  4.159825  25.665347  1.829949  4.038741
# 2           B5      3  1.420272  4.276323  25.407910  1.942105  3.214433
# 3           B5      4  1.337680  4.236697  27.069757  2.073577  3.134529
# 4           B5      5  1.263946  4.142791  26.478353  2.049885  3.729341
# ..         ...    ...       ...       ...        ...       ...       ...
# 675         B7    246  1.381406  4.210231  25.510877  2.037612  3.298042
# 676         B7    247  1.428183  4.209903  28.080145  1.972805  3.698309
# 677         B7    248  1.345410  4.214256  29.098463  1.967716  3.942091
# 678         B7    249  1.407450  4.184595  26.736025  1.979535  3.025646
# 679         B7    250  1.406368  4.186322  28.726130  1.886375  3.424952
#
#           disT       BCt        SOH  RUL
# 0    32.980834  1.986196  99.309790  219
# 1    32.257920  1.986240  99.311985  218
# 2    35.134801  1.984252  99.212608  217
# 3    32.082988  1.969236  98.461812  216
# 4    32.483154  1.974862  98.743106  215
# ..         ...       ...        ...  ...
# 675  34.281706  0.761970  38.098522    4
# 676  30.898516  0.765903  38.295138    3
# 677  30.828397  0.762010  38.100506    2
# 678  32.303220  0.757444  37.872193    1
# 679  33.988588  0.750972  37.548593    0
#
# [680 rows x 11 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   battery_id  680 non-null    object
#  1   cycle       680 non-null    int64
#  2   chI         680 non-null    float64
#  3   chV         680 non-null    float64
#  4   chT         680 non-null    float64
#  5   disI        680 non-null    float64
#  6   disV        680 non-null    float64
#  7   disT        680 non-null    float64
#  8   BCt         680 non-null    float64
#  9   SOH         680 non-null    float64
#  10  RUL         680 non-null    int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 58.6+ KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(df["cycle"], df["SOH"])
plt.xlabel("Cycle")
plt.ylabel("State of health")
plt.title("Battery Degradation Over Cycles")
plt.show()

# %%
import seaborn as sns
numeric_df = df.select_dtypes(include=['number']) # bcz non numeric values like batteryid cause prblm for corr function
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Missing values count:")
print(df.isna().sum())
print()

print("Missing values percentage:")
print((df.isna().mean() * 100).round(2))
# Out:
# Missing values count:
# battery_id    0
# cycle         0
# chI           0
# chV           0
# chT           0
# disI          0
# disV          0
# disT          0
# BCt           0
# SOH           0
# RUL           0
# dtype: int64
#
# Missing values percentage:
# battery_id    0.0
# cycle         0.0
# chI           0.0
# chV           0.0
# chT           0.0
# disI          0.0
# disV          0.0
# disT          0.0
# BCt           0.0
# SOH           0.0
# RUL           0.0
# dtype: float64

# %%
##descriptive statistics
df.describe
# Out:
# <bound method NDFrame.describe of     battery_id  cycle       chI       chV        chT      disI      disV  \
# 0           B5      1  1.440147  4.254682  23.988733  1.894407  3.273523
# 1           B5      2  1.416595  4.159825  25.665347  1.829949  4.038741
# 2           B5      3  1.420272  4.276323  25.407910  1.942105  3.214433
# 3           B5      4  1.337680  4.236697  27.069757  2.073577  3.134529
# 4           B5      5  1.263946  4.142791  26.478353  2.049885  3.729341
# ..         ...    ...       ...       ...        ...       ...       ...
# 675         B7    246  1.381406  4.210231  25.510877  2.037612  3.298042
# 676         B7    247  1.428183  4.209903  28.080145  1.972805  3.698309
# 677         B7    248  1.345410  4.214256  29.098463  1.967716  3.942091
# 678         B7    249  1.407450  4.184595  26.736025  1.979535  3.025646
# 679         B7    250  1.406368  4.186322  28.726130  1.886375  3.424952
#
#           disT       BCt        SOH  RUL
# 0    32.980834  1.986196  99.309790  219
# 1    32.257920  1.986240  99.311985  218
# 2    35.134801  1.984252  99.212608  217
# 3    32.082988  1.969236  98.461812  216
# 4    32.483154  1.974862  98.743106  215
# ..         ...       ...        ...  ...
# 675  34.281706  0.761970  38.098522    4
# 676  30.898516  0.765903  38.295138    3
# 677  30.828397  0.762010  38.100506    2
# 678  32.303220  0.757444  37.872193    1
# 679  33.988588  0.750972  37.548593    0
#
# [680 rows x 11 columns]>

# %%
plt.figure(figsize=(10,5))
for battery in df["battery_id"].unique():
    subset=df[df["battery_id"]==battery]
    plt.plot(subset["cycle"],subset["RUL"],label=battery)




plt.legend()
plt.show()

# %%
import seaborn as sns

numeric_cols = ['cycle', 'chI', 'chV', 'chT', 'disI', 'disV', 'disT', 'BCt', 'SOH', 'RUL']

plt.figure(figsize=(14,6))
sns.boxplot(data=df[numeric_cols])
plt.title("Boxplots of Numeric Features")
#plt.xticks(rotation=45)
plt.show()

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.5883404  0.6774648  ... 0.53138965 0.99396811 0.99396811]
#  [0.00401606 0.55679666 0.38483683 ... 0.46874689 0.99400345 0.99400345]
#  [0.00803213 0.56172123 0.74422629 ... 0.71803758 0.9924041  0.9924041 ]
#  ...
#  [0.99196787 0.46145849 0.55275381 ... 0.34487424 0.00888233 0.00888233]
#  [0.99598394 0.544549   0.46124994 ... 0.47267228 0.00520793 0.00520793]
#  [1.         0.54309959 0.46657818 ... 0.61871467 0.         0.        ]]

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.5883404  0.6774648  ... 0.53138965 0.99396811 0.99396811]
#  [0.00401606 0.55679666 0.38483683 ... 0.46874689 0.99400345 0.99400345]
#  [0.00803213 0.56172123 0.74422629 ... 0.71803758 0.9924041  0.9924041 ]
#  ...
#  [0.99196787 0.46145849 0.55275381 ... 0.34487424 0.00888233 0.00888233]
#  [0.99598394 0.544549   0.46124994 ... 0.47267228 0.00520793 0.00520793]
#  [1.         0.54309959 0.46657818 ... 0.61871467 0.         0.        ]]

# %%
x=df.drop(columns=["battery_id","RUL"])
y=df["RUL"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x) 
print(x_scaled)
# Out:
# [[0.         0.5883404  0.6774648  ... 0.53138965 0.99396811 0.99396811]
#  [0.00401606 0.55679666 0.38483683 ... 0.46874689 0.99400345 0.99400345]
#  [0.00803213 0.56172123 0.74422629 ... 0.71803758 0.9924041  0.9924041 ]
#  ...
#  [0.99196787 0.46145849 0.55275381 ... 0.34487424 0.00888233 0.00888233]
#  [0.99598394 0.544549   0.46124994 ... 0.47267228 0.00520793 0.00520793]
#  [1.         0.54309959 0.46657818 ... 0.61871467 0.         0.        ]]

# %%
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)# this just makes data readable for better debugging
print(x_scaled)
# Out:
#         cycle       chI       chV       chT      disI      disV      disT  \
# 0    0.000000  0.588340  0.677465  0.256110  0.270841  0.419795  0.531390
# 1    0.004016  0.556797  0.384837  0.436231  0.179901  0.827110  0.468747
# 2    0.008032  0.561721  0.744226  0.408574  0.338137  0.388343  0.718038
# 3    0.012048  0.451106  0.621981  0.587108  0.523626  0.345811  0.453588
# 4    0.016064  0.352353  0.332290  0.523573  0.490199  0.662421  0.488264
# ..        ...       ...       ...       ...       ...       ...       ...
# 675  0.983936  0.509669  0.540335  0.419636  0.472884  0.432847  0.644114
# 676  0.987952  0.572317  0.539325  0.695655  0.381451  0.645903  0.350950
# 677  0.991968  0.461458  0.552754  0.805054  0.374270  0.775665  0.344874
# 678  0.995984  0.544549  0.461250  0.551255  0.390945  0.287854  0.472672
# 679  1.000000  0.543100  0.466578  0.765054  0.259510  0.500399  0.618715
#
#           BCt       SOH
# 0    0.993968  0.993968
# 1    0.994003  0.994003
# 2    0.992404  0.992404
# 3    0.980321  0.980321
# 4    0.984848  0.984848
# ..        ...       ...
# 675  0.008850  0.008850
# 676  0.012015  0.012015
# 677  0.008882  0.008882
# 678  0.005208  0.005208
# 679  0.000000  0.000000
#
# [680 rows x 9 columns]

# %%
x_scaled_df=x_scaled.copy()
x_scaled_df["battery_id"]=df["battery_id"].values
x_scaled_df["RUL"]=df["RUL"].values
print(x_scaled_df)
# Out:
#         cycle       chI       chV       chT      disI      disV      disT  \
# 0    0.000000  0.588340  0.677465  0.256110  0.270841  0.419795  0.531390
# 1    0.004016  0.556797  0.384837  0.436231  0.179901  0.827110  0.468747
# 2    0.008032  0.561721  0.744226  0.408574  0.338137  0.388343  0.718038
# 3    0.012048  0.451106  0.621981  0.587108  0.523626  0.345811  0.453588
# 4    0.016064  0.352353  0.332290  0.523573  0.490199  0.662421  0.488264
# ..        ...       ...       ...       ...       ...       ...       ...
# 675  0.983936  0.509669  0.540335  0.419636  0.472884  0.432847  0.644114
# 676  0.987952  0.572317  0.539325  0.695655  0.381451  0.645903  0.350950
# 677  0.991968  0.461458  0.552754  0.805054  0.374270  0.775665  0.344874
# 678  0.995984  0.544549  0.461250  0.551255  0.390945  0.287854  0.472672
# 679  1.000000  0.543100  0.466578  0.765054  0.259510  0.500399  0.618715
#
#           BCt       SOH battery_id  RUL
# 0    0.993968  0.993968         B5  219
# 1    0.994003  0.994003         B5  218
# 2    0.992404  0.992404         B5  217
# 3    0.980321  0.980321         B5  216
# 4    0.984848  0.984848         B5  215
# ..        ...       ...        ...  ...
# 675  0.008850  0.008850         B7    4
# 676  0.012015  0.012015         B7    3
# 677  0.008882  0.008882         B7    2
# 678  0.005208  0.005208         B7    1
# 679  0.000000  0.000000         B7    0
#
# [680 rows x 11 columns]

# %%
feature_col=[col for col in x_scaled_df.columns if col not in ["battery_id","RUL"]]
target_col='RUL'
print("feature column",feature_col)
print(" target column",target_col)
# Out:
# feature column ['cycle', 'chI', 'chV', 'chT', 'disI', 'disV', 'disT', 'BCt', 'SOH']
#  target column RUL

# %%
x_scaled_df.to_csv("processed_data.csv", index=False)

# %%
print(x_scaled_df["battery_id"].unique())
# Out:
# ['B5' 'B6' 'B7']

# %%
train_batteries = ["B5","B6","B18"] 
test_batteries = ["B7"]
print(test_batteries)
#verify no overlap

# print(set(train_batteries)&set(test_batteries))
#intersection
# Out:
# ['B7']

# %%
train_dataset=x_scaled_df[x_scaled_df["battery_id"].isin(train_batteries)]
test_dataset=x_scaled_df[x_scaled_df["battery_id"].isin(test_batteries)]
print(train_dataset["battery_id"].unique())
print(test_dataset["battery_id"].unique())
train_dataset.to_csv("")
# Out:
# ['B5' 'B6' 'B18']
# ['B7']

# %%
import json
split_info={
    "train_batteries":["B5","B6","B18"],
    "test_batteries":["B7"]

}
with open("../data/processed/split.json","w") as f:
    json.dump(split_info,f,indent=4)

# %%
train_dataset.to_csv("../data/processed/train_dataset.csv",index=False)
test_dataset.to_csv("../data/processed/test_dataset.csv",index=False)
